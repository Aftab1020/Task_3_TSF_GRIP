# %% [markdown]
# # ---------------------------------------The Spark Foundation------------------------------------------

# %% [markdown]
# # GRIP(Data Sceince & Buisness Analtytics) Task No. 03

# %% [markdown]
# # **Author : Aftab Aziz Shaikh**

# %% [markdown]
# ### **EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# Now, we are going to Exploratory data analysis on Retails

# %% [markdown]
# Here we are try to find weak areas and where we can work and make good amount of profit

# %% [markdown]
# **Step 1 : Importing important Libraris**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
sns.set()

# %% [markdown]
# **Step 2: Reading the data**

# %%
data = pd.read_csv("SampleSuperstore.csv")

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
data.tail(5)
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# Now, we will check size and shape of the data

# %%
data.size
# Out:
# 129922

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# The Dataset contain 9994 rows and 13 columns

# %% [markdown]
# Getting sample and Information of data

# %%
data.sample(1)
# Out:
#         Ship Mode   Segment        Country         City       State  \
# 7244  First Class  Consumer  United States  Los Angeles  California
#
#       Postal Code Region         Category Sub-Category  Sales  Quantity  \
# 7244        90049   West  Office Supplies          Art  49.56         7
#
#       Discount   Profit
# 7244       0.0  18.8328

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# Now, we will check missing values

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# *So we find that, there is no missing values in dataset*

# %% [markdown]
# **Step 4 : Checking Duplicate Data**

# %%
data.duplicated().sum()
# Out:
# 17

# %% [markdown]
# There are 17 duplicate values

# %% [markdown]
# Now, we will drop duplicate values

# %%
data.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# Postal Code is not important for the analysis so We also drop that column

# %% [markdown]
# **Dropping unnecessary columns**

# %%
column = ['Postal Code']
data= data.drop( columns = column, axis= 6 )

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# Now, you can see we drop the postal code column

# %% [markdown]
# After dropping that column, We have 9994 rows and 12 columns

# %% [markdown]
#  **Step 5 : Data Visualization**

# %% [markdown]
#  Now, I have list of Question to ask the data to find insights and weak point of the data

# %% [markdown]
# **Analsis of Ship Mode**

# %%
plt.figure(figsize = (20,5))
sns.countplot(x = "Ship Mode", data = data)
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='count'>

# %%
plt.figure(figsize=(20,7))
c = sns.barplot(x= "Ship Mode", y = "Profit", data = data)
plt.title("Ship Mode Profit")
plt.xlabel("Ship Mode")
plt.ylabel("Profit")
plt.show()

# %%
plt.figure(figsize=(20,7))
c = sns.barplot(x= "Ship Mode", y = "Discount", data = data)
plt.title("Ship Mode Discount")
plt.xlabel("Ship Mode")
plt.ylabel("Discount")
plt.show()

# %%
plt.figure(figsize = (20,7))
n =sns.barplot('Ship Mode', 'Sales', data = data, orient='v')
plt.title("Ship Mode Sales")
plt.xlabel("Ship Mode")
plt.ylabel("Sales")
n.set_xticklabels(n.get_xticklabels(),rotation = 90)
sns.set_style('whitegrid')
plt.show()

# %%
data_shipmode = data.groupby(['Ship Mode'])[['Sales', 'Profit', 'Discount']]. mean()
data_shipmode
# Out:
#                      Sales     Profit  Discount
# Ship Mode
# First Class     228.497024  31.839948  0.164610
# Same Day        236.396179  29.266591  0.152394
# Second Class    236.089239  29.535545  0.138895
# Standard Class  227.583067  27.494770  0.160023

# %%
figsize = (20,10)
data_shipmode.plot.pie(subplots = True, labels = data_shipmode.index, autopct = '%1.1f%%')
plt.show()

# %% [markdown]
# ### **Insights:**

# %% [markdown]
# ###### **sales**

# %% [markdown]
# Lowest sales: Standard Class(24.5%)

# %% [markdown]
# Highest sales: Same Day(25.5%)

# %% [markdown]
# ###### **Profits**

# %% [markdown]
# Lowest profit: Standard class(23.28%)

# %% [markdown]
# Highest profit: Same Day(26.96%)

# %% [markdown]
# **Analysis On Segment**

# %%
plt.figure(figsize= (20,5))
sns.countplot(x = 'Segment', data = data, palette = "ch:30_r")
plt.title("Segments")
sns.set_style('whitegrid')

# %%
plt.figure(figsize = (20,5))
sns.pairplot(hue = 'Segment', data = data)
sns.set_style('whitegrid')
plt.show()

# %%
data_segment = data.groupby(['Segment'])[['Sales', 'Profit', 'Discount']].mean()
data_segment
# Out:
#                   Sales     Profit  Discount
# Segment
# Consumer     223.733644  25.836873  0.158141
# Corporate    233.823300  30.456667  0.158228
# Home Office  240.972041  33.818664  0.147128

# %%
data_segment.plot.pie(subplots=True, figsize = ( 20, 10),labels = data_segment.index, autopct = '%1.1f%%')
plt.show()

# %%
data_segment.sort_values('Profit')[['Profit', 'Sales']].plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Segment'>

# %% [markdown]
# **Insights :**

# %% [markdown]
# **Sales**

# %% [markdown]
# Lowest sales : Consumer(32.0%)

# %% [markdown]
# Highest sales : Home office(34.5%)

# %% [markdown]
# **Profit**

# %% [markdown]
# Lowest profit : Consemer(28.67%)

# %% [markdown]
# Highest profit : Home office(37.53%)

# %% [markdown]
# There is not difference between classes, still maximum and minimum can be ascertained on seeing in analysis
# The corporates are on the second position for both sales an profits with Home office leading the drive in the
# best way for the company

# %%
data_state = data.groupby(['State'])[['Sales', 'Profit', 'Discount']].mean()
data_state
# Out:
#                             Sales      Profit  Discount
# State
# Alabama                319.846557   94.865989  0.000000
# Arizona                157.508933  -15.303235  0.303571
# Arkansas               194.635500   66.811452  0.000000
# California             228.729451   38.171608  0.072764
# Colorado               176.418231  -35.867351  0.316484
# Connecticut            163.223866   42.823071  0.007317
# Delaware               285.948635  103.930988  0.006250
# District of Columbia   286.502000  105.958930  0.000000
# Florida                233.612815   -8.875461  0.299347
# Georgia                266.825217   88.315453  0.000000
# Idaho                  208.689810   39.367767  0.085714
# Illinois               162.939230  -25.625787  0.390041
# Indiana                359.431946  123.375411  0.000000
# Iowa                   152.658667   39.460397  0.000000
# Kansas                 121.429583   34.851813  0.000000
# Kentucky               263.250000   80.573357  0.000000
# ...

# %%
plt.figure(figsize = (20,10))
sns.countplot(x = data['State'])
plt.title('STATES')
plt.xticks(rotation = 90)
plt.show()
sns.set_style('whitegrid')

# %%
plt.figure(figsize = (20,12))
sns.barplot(x = 'State', y = 'Profit', data = data)
plt.title('PRofit by States')
plt.xlabel('States')
plt.ylabel('Profits')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (20,12))
sns.barplot(x = 'State', y = 'Sales', data = data)
plt.title('Sales by States')
plt.xlabel('States')
plt.ylabel('Sales')
plt.xticks(rotation = 90)
plt.show()

# %%
data_state.sort_values('Profit')[['Profit', 'Sales']].plot(kind = 'bar', figsize = (20,7))
plt.show()
sns.set_style('whitegrid')

# %% [markdown]
# **Insights**

# %% [markdown]
# **Sales**

# %% [markdown]
# Lowest Sales : South dakota(0.81%)

# %% [markdown]
# Highest Sales : Wyoming(11.84%)

# %% [markdown]
# The company should focus on improving their sales in South dakota, kansas, new mexico, north dakota, oregon
# and few more states whose share in sales is miniscule

# %% [markdown]
# **Profits**

# %% [markdown]
# Lowest profit : Ohio(-1.4%)

# %% [markdown]
# Highest profit : Vermont(7.7%)

# %% [markdown]
# The company must ascertain reasons why 10 states are leading to a loss with Ohio leading the charts.
# Either the faults must be corrected or considering the present situation, if the company isn't able
# to come to the break-even point, the operations must be discontinued.

# %% [markdown]
# **Analysis of Region**

# %%
plt.figure(figsize = (20,7))
sns.countplot(x = 'Region', data = data, palette= "ch:25_r")
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.pairplot(hue = 'Region', data = data, palette = "ch:30_r")
plt.show()

# %%
data_region = data.groupby(['Region'])[['Profit', 'Sales']].mean()
data_region
# Out:
#             Profit       Sales
# Region
# Central  17.092709  215.772661
# East     32.135808  238.336110
# South    28.857673  241.803645
# West     33.849032  226.493233

# %%
plt.figure(figsize = (15,7))
data_region.plot.pie(subplots = True, labels = data_region.index.values, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# **Insights**

# %% [markdown]
# **Sales**

# %% [markdown]
# Lowest sales: Central(23.40%)

# %% [markdown]
# Highest sales: South(26.21%)

# %% [markdown]
# The sales seem fine in all the regions since the variation range is less, however steps can still be taken to
# improve the sales in Central zone.

# %% [markdown]
# **Profits**

# %% [markdown]
# Lowest profit: Central(15.27%)

# %% [markdown]
# Highest profit: West(30.25%)

# %% [markdown]
# The profits have to be looked at since the West zone is giving almost double the profit as compared
# to the central one, so the company will have to take steps to analyze the shortcoming in terms of both
# sales and profits for the central region.

# %% [markdown]
# **Analysis of Category and Sub Category**

# %%
plt.figure(figsize = (20,5))
plt.bar('Sub-Category','Category', data = data,)
plt.title('Cateory vs Sub-Category')
plt.xlabel('Sub-category')
plt.ylabel('Category')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.pairplot(data, hue = 'Category')
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.pairplot(data, hue = 'Sub-Category')
plt.show()

# %%
data_subcat = data.groupby(['Sub-Category'])[['Sales', 'Profit']].mean()
data_subcat
# Out:
#                     Sales      Profit
# Sub-Category
# Accessories    215.974604   54.111788
# Appliances     230.755710   38.922758
# Art             34.068834    8.200737
# Binders        133.560560   19.843574
# Bookcases      503.859633  -15.230509
# Chairs         532.332420   43.095894
# Copiers       2198.941618  817.909190
# Envelopes       64.867724   27.418019
# Fasteners       13.936774    4.375660
# Furnishings     95.825668   13.645918
# Labels          34.303055   15.236962
# Machines      1645.553313   29.432669
# Paper           57.284092   24.856620
# Phones         371.211534   50.073938
# Storage        264.590553   25.152277
# Supplies       245.650200   -6.258418
# Tables         648.794771  -55.565771

# %%
data_subcat.sort_values("Profit")[['Profit', 'Sales']].plot(kind = 'bar', figsize = (15,10))
plt.xticks(rotation = 45)
plt.show()

# %%
data_subcat.sort_values('Sales')[['Profit', 'Sales']].plot(kind = 'bar', figsize = (15,10))
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# **Insights**

# %% [markdown]
# **Sales**

# %% [markdown]
# Lowest sales: Fasteners(0.2%)

# %% [markdown]
# Highest sales: Copiers(30.2%)

# %% [markdown]
# **Profit**

# %% [markdown]
# Lowest profit: Tables(-55.6%)

# %% [markdown]
# Highest profit: Copiers(74.7%)

# %% [markdown]
# Looking at the statistical figures, the company must have the main function in copiers since the sales and profits
# are heavily influenced by copiers.

# %% [markdown]
# The company must discontinue the sales of tables since it is contributing to a heavy loss and steps could be
# taken to improve profits for other sub categories.

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# From the above data visualization we can say that profits and sales are high or low. We see that in some sub-categories
# profits are not high the behind reason is company is giving more discounts. They are giving discounts on festivals, end
# of the season. We can improve this by giving prefered range discount so company and consumers both will get benefits.

# %% [markdown]
# # THANK YOU for reading !
